# %%
import librosa, librosa.display
import matplotlib.pyplot as plt
import numpy as np

file = "/Users/andresharisaduvvuri/Documents/GitHub/groupMLProject/ML Brostep/.mp3"

y, sr = librosa.load(file, sr=48000)

librosa.feature.melspectrogram(y=y, sr=sr)

S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=15000)
S_dB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr, fmax=15000)

plt.colorbar(format='%+2.0f dB')
plt.title('Mel-spektrogram')
plt.tight_layout()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/librosa/display.py:974: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/librosa/display.py:974: MatplotlibDeprecationWarning: The 'linthreshy' parameter of __init__() has been renamed 'linthresh' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)

# %%
import os
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

#to play audio
import IPython.display as ipd

audio_fpath = "/Users/andresharisaduvvuri/Documents/GitHub/groupMLProject/ML Brostep/normalized/"
audio_clips = os.listdir(audio_fpath)
print(audio_clips)
print("No. of .wav files in audio folder = ",len(audio_clips))
# Out:
# ['Wooli - The Core.wav', 'Monxx, Codd Dubz - Midnight Hustle.wav', 'Trampa, MARAUDA - Ruckus.wav', 'Wooli, Kompany - Thicc Boi.wav', 'Black Tiger Sex Machine, Blanke - Time Travel.wav', 'Monxx - Falling (VIP).wav', 'PhaseOne, In Hearts Wake - Welcome to Mayhem.wav', 'SVDDEN DEATH - Bleed.wav', 'Seven Lions, Wooli, Trivecta, Nevve - Island (feat. Nevve).wav', 'Kayzo - This Time.wav', 'Kadaver - Combat.wav', 'Flux Pavilion - Got 2 Know.wav', 'Ace Aura - Kaleidoscope.wav', 'PhaseOne - Headstone.wav', 'SVDDEN DEATH, Somnium Sound - Angel Style.wav', 'Dirty Audio, Jupe - Down Under.wav', 'Ponicz - Chopper.wav', '.DS_Store', 'Oliverse - Get High.wav', 'Rudebrat - The Quick and the Dead - Original Mix.wav', 'Pegboard Nerds - Give A Little Love.wav', 'Bear Grillz, SIPPY - Blast Like.wav', 'briddimBomb.wav', 'Badklaat, Kompany - Purge.wav', 'SVDDEN DEATH - Last Life.wav', 'Krimer, Wooli - Stay Out.wav', 'Oddprophet - Check.wav', 'Kompany - Rapture.wav', 'Subtronics - String Theory.wav', "Hi I'm Ghost - Death Rail.wav", 'Subtronics, Squnto - Thunderdome.wav', 'Phiso - Disrespect.wav', 'Wooli - Throw It Up.wav', 'Zomboy, rx Soul - Born To Survive.wav', 'Wooli, MARAUDA, Travis Richter - Elephant March.wav', 'Monxx, KRIMMA - Dungeon.wav', 'Wolfgang Gartner, Aero Chord - Borneo.wav', 'Subtronics, Wooli - Melt Ur Brain.wav', 'Riot Ten, YDG, TRVCY - Hyphy - TRVCY Remix.wav', 'MARAUDA - RIP.wav', 'Ghastly, MOONBOY - Psycho.wav', 'Zomboy - Mind Control.wav', 'MARAUDA - Nefarious.wav', 'Skrillex - Ruffneck - Full Flex.wav', 'Pegboard Nerds - Here It Comes.wav', "Skrillex - Rock 'n' Roll (Will Take You to the Mountain).wav", 'Kompany - Pit.wav', 'Dubloadz - Necronomicon.wav', 'Hekler, Calcium - Doom.wav', 'TRVCY, Jiqui - Almawt.wav', 'SVDDEN DEATH - Caught In A Mosh.wav', 'Marshmello, SVDDEN DEATH - Crusade.wav', 'SVDDEN DEATH, Aweminus - Mr. Muscles.wav', 'MARAUDA - Avoidable cause.wav', 'Subtronics - Nitrous Mafia.wav', 'Skrillex, Sirah - Bangarang (feat. Sirah).wav', 'pulsarBeam.wav', 'Spag Heddy, Tisoki - Jok.wav', 'Modestep, Popeska, xKore - Another Day - xKore Remix.wav', 'SVDDEN DEATH, SNAILS - DEATHMATCH.wav', 'Subtronics - Clockwork.wav', 'Oddprophet, TRVCY - Clean Up.wav', 'Savory - Kilimanjaro.wav', 'Midnight Tyrannosaurus, Subtronics - Revenge Of The Goldfish.wav', 'Rusko - Woo Boost.wav', 'PhaseOne, YOOKiE - State Of Emergency.wav', 'NERO - Doomsday.wav', 'Dirtyphonics, Bassnectar, Ragga Twins - Watch Out.wav', 'TOMYGONE, Hopex - Play.wav', 'SNAILS - FROGKIND.wav', 'Monxx - Giant Sqiddim VIP - MONXX VIP.wav', 'GRiZ - Vibe Check.wav', 'PhaseOne, Subtronics - Demon Hunter.wav', 'Skrillex - Right In.wav', "Skrillex, Wolfgang Gartner - The Devil's Den.wav", 'MARAUDA - Future Stomp.wav', 'Tha Trickaz, Creaky Jackals, PhaseOne - OG Purp - PhaseOne Remix.wav', 'SVDDEN DEATH - Power.wav', 'Dillon Francis, NGHTMRE, ShockOne - Need You - ShockOne Remix.wav', 'DirtySnatcha, MATT DOE - Crashing.wav', 'Skrillex, Damian Marley - Make It Bun Dem.wav', 'Oddprophet - The Hierophant.wav', 'Space Laces, Getter, SVDDEN DEATH - Choppaz - SVDDEN DEATH Remix.wav', 'EH!DE, Spag Heddy - Selecta.wav', '.ipynb_checkpoints', 'SNAILS, Wooli - Snailephant.wav', 'Subtronics, Kompany - Wicked Witch.wav', 'SVDDEN DEATH - Terrible.wav', 'Subtronics, Midnight Tyrannosaurus - Step Aside.wav', 'bubztep.wav', 'Monxx, Emilian Wonk - Carnage.wav', 'Space Laces, Kompany - Overdrive - Kompany Remix.wav', 'MARAUDA - Death Pit.wav', "The Glitch Mob - Can't Kill Us.wav", 'Delta Heavy, Tisoki - White Flag - Tisoki Remix.wav', 'Slooze - Aftermath.wav', 'Rusko, Netsky - Everyday - Netsky Remix.wav', 'LSDREAM - HIGH VIBRATIONS.wav', 'Space Laces - Torque.wav', 'Excision, Wooli - Lockdown.wav', 'Wooli, Detrace - Kong.wav', 'Fedde Le Grand, DI-RECT, Zomboy - Where We Belong - Zomboy Remix.wav', 'Deafmind - Trvp or Die [VIP].wav', 'SNAILS, Sullivan King, Big Ali, MARAUDA - King Is Back - MARAUDA Remix.wav', 'Alexander Lewis, KRANE - Fall Apart.wav', 'Krimer, Spag Heddy - Got Dam!.wav' ...
# No. of .wav files in audio folder =  106

# %%
x, sr = librosa.load('/Users/andresharisaduvvuri/Downloads/psychosocial.wav')

#print(type(x), type(sr))
#print(x.shape, sr)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     145     try:
# --> 146         with sf.SoundFile(path) as sf_desc:
#     147             sr_native = sf_desc.samplerate
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1182             raise TypeError("Invalid file: {0!r}".format(self.name))
# -> 1183         _error_check(_snd.sf_error(file_ptr),
#    1184                      "Error opening {0!r}: ".format(self.name))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/soundfile.py in _error_check(err, prefix)
#    1356         err_str = _snd.sf_error_number(err)
# -> 1357         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1358
#
# RuntimeError: Error opening '/Users/andresharisaduvvuri/Documents/GitHub/groupMLProject/ML Brostep/normalized/briddimBomb.wav': Format not recognised.
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# <ipython-input-18-61af00ca66f5> in <module>
# ----> 1 x, sr = librosa.load('/Users/andresharisaduvvuri/Documents/GitHub/groupMLProject/ML Brostep/normalized/briddimBomb.wav')
#       2
#       3 #print(type(x), type(sr))
#       4 #print(x.shape, sr)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     161         if isinstance(path, (str, pathlib.PurePath)):
#     162             warnings.warn("PySoundFile failed. Trying audioread instead.")
# --> 163             y, sr_native = __audioread_load(path, offset, duration, dtype)
#     164         else:
#     165             raise (exc)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     185
#     186     y = []
# --> 187     with audioread.audio_open(path) as input_file:
#     188         sr_native = input_file.samplerate
#     189         n_channels = input_file.channels
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/audioread/__init__.py in audio_open(path, backends)
#     109     for BackendClass in backends:
#     110         try:
# --> 111             return BackendClass(path)
#     112         except DecodeError:
#     113             pass
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/audioread/rawread.py in __init__(self, filename)
#      63
#      64         try:
# ---> 65             self._file = aifc.open(self._fh)
#      66         except aifc.Error:
#      67             # Return to the beginning of the file to try the next reader.
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/aifc.py in open(f, mode)
#     915             mode = 'rb'
#     916     if mode in ('r', 'rb'):
# --> 917         return Aifc_read(f)
#     918     elif mode in ('w', 'wb'):
#     919         return Aifc_write(f)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/aifc.py in __init__(self, f)
#     356         else:
#     357             # assume it is an open file object already
# --> 358             self.initfp(f)
#     359
#     360     def __enter__(self):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/aifc.py in initfp(self, file)
#     312         self._soundpos = 0
#     313         self._file = file
# --> 314         chunk = Chunk(file)
#     315         if chunk.getname() != b'FORM':
#     316             raise Error('file does not start with FORM id')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/chunk.py in __init__(self, file, align, bigendian, inclheader)
#      61         self.chunkname = file.read(4)
#      62         if len(self.chunkname) < 4:
# ---> 63             raise EOFError
#      64         try:
#      65             self.chunksize = struct.unpack_from(strflag+'L', file.read(4))[0]
#
# EOFError:
